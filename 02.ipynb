# %% [markdown]
# <a href="https://colab.research.google.com/github/VitorMadu/Estudos-de-Dados/blob/main/02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1) Escreva um programa que peça à pessoa usuária para fornecer dois números e exibir o número maior.

2) Escreva um programa que solicite o percentual de crescimento de produção de uma empresa e informe se houve um crescimento (porcentagem positiva) ou decrescimento (porcentagem negativa).

3) Escreva um programa que determine se uma letra fornecida pela pessoa usuária é uma vogal ou consoante.

# %%
valor_1 = int(input("Digite o primeiro valor: "))
valor_2 = int(input("Digite o segundo valor: "))
if valor_1 > valor_2:
    print(f"O maior valor é {valor_1}")
else :
    print(f"O maior valor é {valor_2}")
# Out:
# Digite o primeiro valor: 2
# Digite o segundo valor: 3
# O maior valor é 3

# %%
porcentual_crescimento = float(input("Digite o percentual de crescimento: "))
if porcentual_crescimento > 0:
    print("Houve um crescimento")
elif porcentual_crescimento < 0:
    print("Houve um decrescimento")
# Out:
# Digite o percentual de crescimento: 10
# Houve um crescimento

# %%
letra_fornecida = input("Digite uma letra: ")
if letra_fornecida == "a" or letra_fornecida == "e" or letra_fornecida == "i" or letra_fornecida == "o" or letra_fornecida == "u":
  print("é uma vogal")
else:
  print("é uma consoante")
# Out:
# Digite uma letra: a
# é uma vogal

# %%
valor_medio1 = float(input("valor medio do carro no 1° ano: "))
valor_medio2 = float(input("valor medio do carro no 2° ano: "))
valor_medio3 = float(input("valor medio do carro no 3° ano: "))
if valor_medio1 > valor_medio2 > valor_medio3:
  print(f"O maior valor é {valor_medio1} e o menor valor é {valor_medio3}")
elif valor_medio1 > valor_medio3 > valor_medio2:
  print(f"O maior valor é {valor_medio1} e o menor valor é {valor_medio2}")
elif valor_medio2 > valor_medio1 > valor_medio3:
  print(f"O maior valor é {valor_medio2} e o menor valor é {valor_medio3}")
elif valor_medio2 > valor_medio3 > valor_medio1:
  print(f"O maior valor é {valor_medio2} e o menor valor é {valor_medio1}")
elif valor_medio3 > valor_medio1 > valor_medio2:
  print(f"O maior valor é {valor_medio3} e o menor valor é {valor_medio2}")
elif valor_medio3 > valor_medio2 > valor_medio1:
  print(f"O maior valor é {valor_medio3} e o menor valor é {valor_medio1}")
# Out:
# valor medio do carro no 1° ano: 12
# valor medio do carro no 2° ano: 23
# valor medio do carro no 3° ano: 30
# O maior valor é 30.0 e o menor valor é 12.0

# %%
Produto1 = float(input("valor do 1° produto: "))
Produto2 = float(input("vvalor do 2° produto: "))
Produto3 = float(input("valor do 3° produto: "))
if Produto1 < Produto2 < Produto3:
  print("Produto 1 é o mais barato para comprar")
elif Produto2 < Produto1 <Produto3:
  print("Produto 2 é o mais barato para comprar")
else:
  print("produto 3 é o mais barato para se comprar")
# Out:
# valor do 1° produto: 30
# vvalor do 2° produto: 21
# valor do 3° produto: 10
# produto 3 é o mais barato para se comprar

# %% [markdown]
# 6) Escreva um programa que leia três números e os exiba em ordem decrescente.
#
# 7) Escreva um programa que pergunte em qual turno a pessoa usuária estuda ("manhã", "tarde" ou "noite") e exiba a mensagem "Bom Dia!", "Boa Tarde!", "Boa Noite!", ou "Valor Inválido!", conforme o caso.

# %%
valor_1 = int(input("Digite o primeiro valor: "))
valor_2 = int(input("Digite o segundo valor: "))
valor_3 = int(input("Digite o terceiro valor: "))
if valor_1 > valor_2 and valor_1 > valor_3:
  if valor_2 >= valor_3:
    print(f"{valor_1}, {valor_2}, {valor_3}")
  else:
    print(f"{valor_1}, {valor_3}, {valor_2}")
elif valor_2 > valor_1 and valor_2 > valor_3:
  if valor_1 >= valor_3:
    print(f"{valor_2}, {valor_1}, {valor_3}")
  else:
    print(f"{valor_2}, {valor_3}, {valor_1}")
else:
  if valor_1 >= valor_2:
    print(f"{valor_3}, {valor_1}, {valor_2}")
  else:
    print(f"{valor_3}, {valor_2}, {valor_1}")
# Out:
# Digite o primeiro valor: 123
# Digite o segundo valor: 23
# Digite o terceiro valor: 52
# 123, 52, 23

# %%
turno_1 = input("digite o turno em que estuda (manhã, tarde ou noite): ")
if turno_1 == "manhã":
  print("bom dia")
elif turno_1 == "tarde":
  print("boa tarde")
elif turno_1 == "noite":
  print("boa noite")
else:
  print("valor inválido")
# Out:
# digite o turno em que estuda (manhã, tarde ou noite): dsad
# valor inválido

# %% [markdown]
# 9 Escreva um programa que peça um número inteiro à pessoa usuária e determine se ele é par ou ímpar. Dica: Você pode utilizar o operador módulo %.
#
# 10 Escreva um programa que peça um número à pessoa usuária e informe se ele é inteiro ou decimal.

# %%
valor = int(input("digite um número inteiro: "))
if valor %2 == 0:
 print("o valor é par")
else:
  print("valor é impar")
# Out:
# digite um número inteiro: 36
# o valor é par

# %%
valor = float(input("digite um número: "))
if valor %1 == 0:
  print("o valor é inteiro")
else:
  print("o valor é decimal")
# Out:
# digite um número: 25.23651
# o valor é decimal

# %% [markdown]
# Momento dos projetos
#
# 10) Um programa deve ser escrito para ler dois números e, em seguida, perguntar à pessoa usuária qual operação ele deseja realizar. O resultado da operação deve incluir informações sobre o número - se é par ou ímpar, positivo ou negativo e inteiro ou decimal.

# %%
valor_1 = float(input("digite o primeiro valor: "))
valor_2 = float(input("digite o segundo valor: "))
operação = str(input("qual operação voce deseja realizar(par ou ímpar, positivo ou negativo e inteiro ou decimal)? "))
if operação == "par ou ímpar":
  if valor_1 %2 == 0:
    print("valor 1 é par")
  else:
    print("valor 1 é impar")
  if valor_2 %2 == 0:
    print("valor 2 é par")
  else:
    print("valor 2 é impar")
if operação == "positivo ou negativo":
  if valor_1 > 0 :
    print("valor é positivo")
  else:
    print("valor é negativo")
  if valor_2 > 0:
    print("valor é positivo")
  else:
    print("valor é negativo")
if operação == "inteiro ou decimal":
  if valor_1 %1 == 0:
    print("o valor 1 é inteiro")
  else:
    print("o valor 1 é decimal")
  if valor %1 == 0:
    print("o valor 2 é inteiro")
  else:
    print("o valor 2 é decimal")
# Out:
# digite o primeiro valor: -96
# digite o segundo valor: 62
# qual operação voce deseja realizar(par ou ímpar, positivo ou negativo e inteiro ou decimal)? positivo ou negativo
# valor é negativo
# valor é positivo

# %% [markdown]
# 11) Escreva um programa que peça à pessoa usuária três números que representam os lados de um triângulo. O programa deve informar se os valores podem ser utilizados para formar um triângulo e, caso afirmativo, se ele é equilátero, isósceles ou escaleno. Tenha em mente algumas dicas:
#
# Três lados formam um triângulo quando a soma de quaisquer dois lados for maior que o terceiro;
# Triângulo Equilátero: três lados iguais;
# Triângulo Isósceles: quaisquer dois lados iguais;
# Triângulo Escaleno: três lados diferentes.

# %%
valor_1 = float(input("Digite o primeiro valor: "))
valor_2 = float(input("Digite o segundo valor: "))
valor_3 = float(input("Digite o terceiro valor: "))

if valor_1 + valor_2 > valor_3 and valor_1 + valor_3 > valor_2 and valor_2 + valor_3 > valor_1:

    if valor_1 == valor_2 == valor_3:
        print("Triângulo Equilátero")

    elif valor_1 == valor_2 or valor_1 == valor_3 or valor_2 == valor_3:
        print("Triângulo Isósceles")

    else:
        print("Triângulo Escaleno")

else:
    print("Os valores não formam um triângulo")
# Out:
# Digite o primeiro valor: 23
# Digite o segundo valor: 23
# Digite o terceiro valor: 0
# Os valores não formam um triângulo

# %% [markdown]
# 12) Um estabelecimento está vendendo combustíveis com descontos variados. Para o etanol, se a quantidade comprada for até 15 litros, o desconto será de 2% por litro. Caso contrário, será de 4% por litro. Para o diesel, se a quantidade comprada for até 15 litros, o desconto será de 3% por litro. Caso contrário, será de 5% por litro. O preço do litro de diesel é R$ 2,00 e o preço do litro de etanol é R$ 1,70. Escreva um programa que leia a quantidade de litros vendidos e o tipo de combustível (E para etanol e D para diesel) e calcule o valor a ser pago pelo cliente. Tenha em mente algumas dicas:
#
# O do valor do desconto será a multiplicação entre preço do litro, quantidade de litros e o valor do desconto.
# O valor a ser pago por um cliente será o resultado da multiplicação do preço do litro pela quantidade de litros menos o valor de desconto resultante do cálculo.

# %%
tipo_combustível = str(input("qual tipo de combustível voce quer(etanol ou diesel? )"))
qt_combustível = float(input("quantos litros: "))

if tipo_combustível == "etanol":
  preço = 1.70

  if qt_combustível <= 15:
    desconto = 0.02
  else:
    desconto = 0.04
elif tipo_combustível == "diesel":
    preço = 2.00

    if qt_combustível <= 15:
        desconto = 0.03
    else:
        desconto = 0.05
valor_desconto = preço * qt_combustível * desconto
valor_final = preço * qt_combustível - valor_desconto
print(f"o valor a ser pago é: {valor_final}")
# Out:
# qual tipo de combustível voce quer(etanol ou diesel? )diesel
# quantos litros: 10
# o valor a ser pago é: 19.4

# %% [markdown]
# 13) Em uma empresa de venda de imóveis você precisa criar um código que analise os dados de vendas anuais para ajudar a diretoria na tomada de decisão. O código precisa coletar os dados de quantidade de venda durante os anos de 2022 e 2023 e fazer um cálculo de variação percentual. A partir do valor da variação, deve ser enviada às seguintes sugestões:
#
# Para variação acima de 20%: bonificação para o time de vendas.
#
# Para variação entre 2% e 20%: pequena bonificação para time de vendas.
#
# Para variação entre 2% e -10%: planejamento de políticas de incentivo às vendas.
#
# Para variação abaixo de -10%: corte de gastos.

# %%
qt_vendas_2022 = float(input("digite a quantidade de vendas do ano de 2022: "))
qt_vendas_2023 = float(input("digite a quantidade de vendas do ano de 2023: "))
Variação_percentual= ((qt_vendas_2023 - qt_vendas_2022) / qt_vendas_2022)*100
print(Variação_percentual)
if Variação_percentual > 20:
  print("bonifação para o time de vendas")
  if Variação_percentual >= 2 and Variação_percentual <= 20:
    print("pequena bonificação para time de vendas")
  elif Variação_percentual <=2 and Variação_percentual >= -10:
    print("planejamento de políticas de incentivo às vendas.")
else:
    print("corte de gastos")
# Out:
# digite a quantidade de vendas do ano de 2022: -300
# digite a quantidade de vendas do ano de 2023: 250
# -183.33333333333331
# corte de gastos
